# %% [markdown]
# # Chess Engine Training - Google Colab
#
# This notebook is for training the chess engine model on GPU.
#
# ## Setup

# %%
# Mount Google Drive (optional, for persistent storage)
from google.colab import drive
drive.mount('/content/drive')

# %%
# Clone repository
# !git clone <YOUR_REPO_URL> /content/ChessEngine
# %cd /content/ChessEngine

# %%
# Install dependencies
# !pip install -r requirements.txt

# %%
# Verify GPU is available
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"CUDA version: {torch.version.cuda}")

# %% [markdown]
# ## Import Modules

# %%
# Import project modules
import sys
sys.path.append('/content/ChessEngine')

from config import *
from data_pipeline import *
from train_stub import *
from model import *
from board_encoding import *

import chess
import torch
import numpy as np

# %% [markdown]
# ## Training

# %%
# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# %%
# Initialize model
# model = YourModel()
# model.to(device)

# Training loop
# train(model, device, ...)

# %% [markdown]
# ## Save Results

# %%
# Save model to Google Drive
# torch.save(model.state_dict(), '/content/drive/MyDrive/ChessEngine/models/model.pth')

# Save data
# !cp -r /content/ChessEngine/data /content/drive/MyDrive/ChessEngine/
# !cp -r /content/ChessEngine/logs /content/drive/MyDrive/ChessEngine/
